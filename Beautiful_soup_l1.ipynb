# %% [markdown]
# ## Beautiful Soup Introduction

# %% [markdown]
# Read the page and store the data in the variable.

# %%
from urllib.request import urlopen
html = urlopen('http://pythonscraping.com/pages/page1.html')

# %%
print(html.read())
# Out:
# b'<html>\n<head>\n<title>A Useful Page</title>\n</head>\n<body>\n<h1>An Interesting Title</h1>\n<div>\nLorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.\n</div>\n</body>\n</html>\n'

# %%
# Read the single HTML file 
! pip install beautifulsoup4

# %%
# Import the beautiful soup from the pacage
from bs4 import BeautifulSoup
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Import the beautiful soup from the pacage
# ----> 2 from bs4 import BeautifulSoup
#
# ModuleNotFoundError: No module named 'bs4'

# %% [markdown]
# Creating **Virual environment** to not confilt in different model of pacages.

# %%
# Install Virtual env in your Computer .
! pip install virtualenv
# Out:
# ...
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/5.5 MB 1.7 MB/s eta 0:00:03
#    --------- ------------------------------ 1.3/5.5 MB 2.7 MB/s eta 0:00:02
#    -------------------- ------------------- 2.9/5.5 MB 4.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.9/5.5 MB 4.6 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 4.3 MB/s  0:00:01
# ...
#
#    ---------------------------------------- 0/4 [distlib]
#    ---------- ----------------------------- 1/4 [filelock]
#    -------------------- ------------------- 2/4 [python-discovery]
#    ------------------------------ --------- 3/4 [virtualenv]
#    ------------------------------ --------- 3/4 [virtualenv]
# ...

# %%
# Creating Virtual env with name (**scrapingEnv**)
! python -m venv scrapingEnv

# %%
from urllib.request import urlopen

# %%
# Installing the parsing function of HTML
! pip3 install lxml

# %%
# Make variable to store the function. 
bs = BeautifulSoup(html.read(), 'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 bs = BeautifulSoup(html.read(), 'lxml')
#
# NameError: name 'BeautifulSoup' is not defined

# %%
# For error in urllib handle Use this Function
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
try:
 html = urlopen('https://pythonscrapingthisurldoesnotexist.com')
except HTTPError as e:
 print(e)
except URLError as e:
 print('The server could not be found!')
else:
 print('It Worked!')
# Out:
# The server could not be found!

# %%
# Check the tag is available in the website or not ? 
print(bs.nonExistentTag.someTag)

# %%
# Handle the attribute errors. 
try:
    badContent = bs.nonExistingTag.anotherTag
except AttributeError as e:
    print('Tag was not found')
else:
 if badContent == None:
    print ('Tag was not found')
 else:
    print(badContent)
